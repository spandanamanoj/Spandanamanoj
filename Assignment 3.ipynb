# %%
for i in range(1,11):
    for j in range(1,11):
        print(i,'x',j, '=', i*j)
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# ...

# %%
for i in range(1,1000):
    if(i%2 == 0):
        print(i, "is the prime number:")
    else:
        print(i, "is not the prime number:")
# Out:
# 1 is not the prime number:
# 2 is the prime number:
# 3 is not the prime number:
# 4 is the prime number:
# 5 is not the prime number:
# 6 is the prime number:
# 7 is not the prime number:
# 8 is the prime number:
# 9 is not the prime number:
# 10 is the prime number:
# 11 is not the prime number:
# 12 is the prime number:
# 13 is not the prime number:
# 14 is the prime number:
# 15 is not the prime number:
# 16 is the prime number:
# 17 is not the prime number:
# 18 is the prime number:
# 19 is not the prime number:
# 20 is the prime number:
# 21 is not the prime number:
# 22 is the prime number:
# 23 is not the prime number:
# 24 is the prime number:
# 25 is not the prime number:
# 26 is the prime number:
# 27 is not the prime number:
# 28 is the prime number:
# 29 is not the prime number:
# 30 is the prime number:
# 31 is not the prime number:
# 32 is the prime number:
# 33 is not the prime number:
# 34 is the prime number:
# 35 is not the prime number:
# 36 is the prime number:
# ...

# %%
n = int(input("Enter the percentage:"))
if n>90:
    print("Excelent")
elif(n>75):
    print("Good")
elif(n>60):
    print("First class")
else:
    print("Second class")
# Out:
# Enter the percentage:80
# Good

# %%
x = int(input("Enter the number:"))
i=1
while (i <= x):
    if(i%2 == 0):
        print(i,"is the prime number")
        i = i+1
    else:
        print(i,"is not the prime number")
        i = i+1
# Out:
# Enter the number:10
# 1 is not the prime number
# 2 is the prime number
# 3 is not the prime number
# 4 is the prime number
# 5 is not the prime number
# 6 is the prime number
# 7 is not the prime number
# 8 is the prime number
# 9 is not the prime number
# 10 is the prime number
