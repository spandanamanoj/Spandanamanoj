# %% [markdown]
# # Try 5 Different functions of the String in Python.

# %%
Name = "thanks to lets upgrade"

# %%
Name
# Out:
# 'thanks to lets upgrade'

# %% [markdown]
# # catitalize the first string

# %%
name = Name.capitalize()

# %%
name
# Out:
# 'Thanks to lets upgrade'

# %% [markdown]
# # Checking whether all letters are in lowercase

# %%
name.islower()
# Out:
# False

# %% [markdown]
# # Replace the first string

# %%
x=name.replace("Thanks","hello")

# %%
x
# Out:
# 'hello to lets upgrade'

# %% [markdown]
# # join a string to an existed string

# %%
a = 'Hello,'
s = " ".join((a,name))

# %%
s
# Out:
# 'Hello, Thanks to lets upgrade'

# %% [markdown]
# # Center aligning the string with some special characters

# %%
s.center(35,"\N{BLACK HEART SUIT}")
# Out:
# '♥♥♥Hello, Thanks to lets upgrade♥♥♥'

# %% [markdown]
# # Fun with coding

# %%
R = s.split()

# %%
R
# Out:
# ['Hello,', 'Thanks', 'to', 'lets', 'upgrade']

# %% [markdown]
# # Converting list to tuple

# %%
MT = tuple(R)

# %%
MT
# Out:
# ('Hello,', 'Thanks', 'to', 'lets', 'upgrade')

# %%
M = "\U0001f600".join(MT)

# %%
M
# Out:
# 'Hello,😀Thanks😀to😀lets😀upgrade'

# %% [markdown]
# # Try 5 Different functions of the List object in Python

# %%
list = [7, 9, 1, 5, 19,15,25,21]

# %%
list.sort()

# %%
list
# Out:
# [1, 5, 7, 9, 15, 19, 21, 25]

# %%
list.append(40)

# %%
list
# Out:
# [1, 5, 7, 9, 15, 19, 21, 25, 40]

# %%
list.index(21)
# Out:
# 6

# %%
max(list)
# Out:
# 40

# %%
min(list)
# Out:
# 1

# %%
list.extend([30,35])

# %%
list
# Out:
# [1, 5, 7, 9, 15, 19, 21, 25, 40, 30, 35]

# %%
len(list)
# Out:
# 11

# %%
type(list)
# Out:
# list

# %%
list1 = [70,25,75]

# %%
for i in list:
    if i in list1:
        print(i)
# Out:
# 25

# %% [markdown]
# # Experiment with at least 5 default functions of Dictionary

# %%
student = {"Rani": "60%",
          "Ravi":"70%",
          "Raju":"80%"}
X = student.get("Rani")
print(X)
# Out:
# 60%

# %%
student.copy()
# Out:
# {'Rani': '60%', 'Ravi': '70%', 'Raju': '80%'}

# %%
student.update({"Ramu":"90%"})

# %%
student
# Out:
# {'Rani': '60%', 'Ravi': '70%', 'Raju': '80%', 'Ramu': '90%'}

# %%
student.values()
# Out:
# dict_values(['60%', '70%', '80%', '90%'])

# %%
student.setdefault("Rani","90%")
# Out:
# '60%'

# %%
student.pop("Ravi")
# Out:
# '70%'

# %%
student
# Out:
# {'Rani': '60%', 'Raju': '80%', 'Ramu': '90%'}

# %%
student.items()
# Out:
# dict_items([('Rani', '60%'), ('Raju', '80%'), ('Ramu', '90%')])
